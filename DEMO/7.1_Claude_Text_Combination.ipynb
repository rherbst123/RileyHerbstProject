# %%
import os
import requests
import time

# %%
API_KEY             = "API-KEY"  
MODEL_NAME          = "claude-3-7-sonnet-20250219"  

SYSTEM_PROMPT_FILE  = r"C:\Users\Riley\Documents\GitHub\RileyHerbstProject\Prompts\SystemPrompt.txt"
USER_PROMPT_FILE    = r"C:\Users\Riley\Documents\GitHub\RileyHerbstProject\Prompts\Prompt_1.5.3.txt"

TEXT_FOLDER         = r"C:\Users\Riley\Documents\GitHub\RileyHerbstProject\DEMO\OCR_Text_Image\Finished"

# %%
def read_text(path: str) -> str:
    with open(path, "r", encoding="utf-8") as f:
        return f.read()

def get_text_files(folder: str):
    return sorted(
        fn for fn in os.listdir(folder)
        if os.path.isfile(os.path.join(folder, fn)) and fn.lower().endswith(".txt")
    )

# load prompts
system_prompt = read_text(SYSTEM_PROMPT_FILE)
user_prompt   = read_text(USER_PROMPT_FILE)
text_files    = get_text_files(TEXT_FOLDER)
print(f"Found {len(text_files)} text files.")

# Anthropic headers
headers = {
    "Content-Type": "application/json",
    "x-api-key": API_KEY,
}

start_time = time.time()


for idx, filename in enumerate(text_files, 1):
        file_path = os.path.join(TEXT_FOLDER, filename)
        file_text = read_text(file_path)

        # combine user prompt + file contents
        user_message = f"{user_prompt}\n\n{file_text}"

        payload = {
            "model": MODEL_NAME,
            "messages": [
                {"role": "system", "content": system_prompt},
                {"role": "user",   "content": user_message},
            ],
            "max_tokens_to_sample": 4096,
            "temperature": 0.0,
        }

        print(f"Processing {idx}/{len(text_files)}: {filename}")
        resp = requests.post(
            "https://api.anthropic.com/v1/chat/completions",
            headers=headers,
            json=payload
        )
        data = resp.json()
        if resp.ok:
            reply = data["choices"][0]["message"]["content"].strip()
        else:
            reply = f"Error {resp.status_code}: {data}"

        print(reply)
        print(50*"=")
        

       

        # Wait 1 second before the next API call
        time.sleep(2)

elapsed = time.time() - start_time
print(f"Done in {elapsed:.1f}s")
# Out:
# Found 10 text files.
# Processing 1/10: sat_0001_V0573776F_corrected_transcripts.txt
# verbatimCollectors: Dr. EDGAR A. MEARNS, Collector
#
# collectedBy: E A Mearns
#
# secondaryCollectors: N/A
#
# recordNumber: 2832
#
# verbatimEventDate: Jan. 10 to Feb. 2, 1910
#
# minimumEventDate: 1910-01-10
#
# maximumEventDate: 1910-02-02
#
# verbatimIdentification: Cyperus callistus Ridley
#
# latestScientificName: Cyperus maculatus Böck.
#
# identifiedBy: J Raynal
#
# verbatimDateIdentified: 19.10.1971
#
# associatedTaxa: N/A
#
# country: Congo Free State
#
# firstPoliticalUnit: Lado Enclave
#
# secondPoliticalUnit: N/A
#
# municipality: N/A
#
# verbatimLocality: "Rhino Camp," Bahr el Jebel, Lado Enclave, Congo Free State
#
# locality: "Rhino Camp," Bahr el Jebel, Lado Enclave, Congo Free State
#
# habitat: N/A
#
# verbatimElevation: N/A
#
# verbatimCoordinates: N/A
#
# otherCatalogNumbers: N/A
#
# originalMethod: Typed
#
# typeStatus: no type status
# ==================================================
# Processing 2/10: sat_0002_V0576008F_corrected_transcripts.txt
# verbatimCollectors: COLL. F. G. OVERLAET
# collectedBy: F G Overlaet
# secondaryCollectors: N/A
# recordNumber: s.n.
# verbatimEventDate: 1923-4
# minimumEventDate: 1923-00-00
# maximumEventDate: 1924-00-00
# verbatimIdentification: Habenaria
# latestScientificName: Habenaria
# identifiedBy: B Pettersson
# verbatimDateIdentified: 1984
# associatedTaxa: N/A
# country: Belgian Congo
# firstPoliticalUnit: N/A
# secondPoliticalUnit: N/A
# municipality: N/A
# verbatimLocality: N/A
# locality: [precise locality unknown]
# habitat: N/A
# verbatimElevation: N/A
# verbatimCoordinates: N/A
# otherCatalogNumbers: 752356
# originalMethod: Typed
# typeStatus: no type status
# ==================================================
# Processing 3/10: sat_0003_V0576279F_corrected_transcripts.txt
# verbatimCollectors: R. A. Maas Geesteranus
# collectedBy: R A Maas Geesteranus
# secondaryCollectors: N/A
# recordNumber: 4924
# verbatimEventDate: 14-VI 1949
# minimumEventDate: 1949-06-14
# maximumEventDate: N/A
# verbatimIdentification: Pycreus segmentatus C.B.Cl.
# latestScientificName: Pycreus segmentatus C.B.Cl.
# identifiedBy: N/A
# verbatimDateIdentified: N/A
# associatedTaxa: Dombeya mastersii and Olea hochstetteri
# country: Kenya
# firstPoliticalUnit: Nyanza
# secondPoliticalUnit: Londiani
# municipality: N/A
# verbatimLocality: Nyanza Province, Londiani Distr., Tinderet Forest Reserve, Camp I, lat. 0° 5' S., long. 35° 27' E.
# locality: Nyanza Province, Londiani Distr., Tinderet Forest Reserve, Camp I, lat. 0° 5' S., long. 35° 27' E.
# habitat: glade surrounded by rather open, tall forest, containing a.o. Dombeya mastersii and Olea hochstetteri
# verbatimElevation: 2260 m s.m.
# verbatimCoordinates: lat. 0° 5' S., long. 35° 27' E.
# otherCatalogNumbers: 1735
# originalMethod: Typed
# typeStatus: no type status
# ==================================================
# Processing 4/10: sat_0004_V0577013F_corrected_transcripts.txt
# verbatimCollectors: J. M. et B. Reitsma
#
# collectedBy: J M Reitsma
#
# secondaryCollectors: B Reitsma
#
# recordNumber: 2013
#
# verbatimEventDate: 3-3-86
#
# minimumEventDate: 1986-03-03
#
# maximumEventDate: N/A
#
# verbatimIdentification: Bulbophyllum scaberulum (Rolfe) Bolus var. scaberulum
#
# latestScientificName: Bulbophyllum scaberulum (Rolfe) Bolus var. scaberulum
#
# identifiedBy: O Komarova
#
# verbatimDateIdentified: 1985
#
# associatedTaxa: N/A
#
# country: Gabon
#
# firstPoliticalUnit: N/A
#
# secondPoliticalUnit: N/A
#
# municipality: N/A
#
# verbatimLocality: Primary rain forest, ca 6 km NW of Oveng, chantier Rougier Océan. 0° 41' N x 11° 07' E
#
# locality: Primary rain forest, ca 6 km NW of Oveng, chantier Rougier Océan
#
# habitat: Epiphytic orchid, growing in big clumps together. Flowers greenish-yellow. Leaves hard, succulent
#
# verbatimElevation: N/A
#
# verbatimCoordinates: 0° 41' N x 11° 07' E
#
# otherCatalogNumbers: 2310219
#
# originalMethod: Typed
#
# typeStatus: no type status
# ==================================================
# Processing 5/10: sat_0005_V0577892F_corrected_transcripts.txt
# verbatimCollectors: Carvalho 2102
#
# collectedBy: Carvalho
#
# secondaryCollectors: N/A
#
# recordNumber: 2102
#
# verbatimEventDate: 26-VII-1986
#
# minimumEventDate: 1986-07-26
#
# maximumEventDate: N/A
#
# verbatimIdentification: Mariscus alternifolius Vahl
#
# latestScientificName: Mariscus alternifolius Vahl
#
# identifiedBy: C. Cebolla & M A. Rivas Ponce (UAM)
#
# verbatimDateIdentified: 1995
#
# associatedTaxa: N/A
#
# country: Equatorial Guinea
#
# firstPoliticalUnit: Bioco
#
# secondPoliticalUnit: N/A
#
# municipality: Malabo
#
# verbatimLocality: «Malabo, finca las Carboneras, 32NMK7415, 8 m. Bosque secundario y terrenos incultos. Herbácea, 20-30 cm»
#
# locality: Malabo, finca las Carboneras, Bosque secundario y terrenos incultos. Herbácea, 20-30 cm
#
# habitat: Bosque secundario y terrenos incultos
#
# verbatimElevation: 8 m
#
# verbatimCoordinates: 32NMK7415
#
# otherCatalogNumbers: N/A
#
# originalMethod: Typed
#
# typeStatus: no type status
# ==================================================
# Processing 6/10: sat_0006_V0578553F_corrected_transcripts.txt
# verbatimCollectors: Fernández Casas 11206
# collectedBy: F Casas
# secondaryCollectors: N/A
# recordNumber: 11206
# verbatimEventDate: 5-II-1989
# minimumEventDate: 1989-02-05
# maximumEventDate: N/A
# verbatimIdentification: Agrostis manii (Hooker fil.) Stapf
# latestScientificName: Agrostis manii (Hooker fil.) Stapf
# identifiedBy: C Cebolla | M A Rivas Ponce
# verbatimDateIdentified: 1993
# associatedTaxa: N/A
# country: Equatorial Guinea
# firstPoliticalUnit: Bioco
# secondPoliticalUnit: N/A
# municipality: N/A
# verbatimLocality: cumbre del pico Basilé, 32NMJ7396, 2870 m, márgenes de la pista
# locality: cumbre del pico Basilé, márgenes de la pista
# habitat: márgenes de la pista
# verbatimElevation: 2870 m
# verbatimCoordinates: 32NMJ7396
# otherCatalogNumbers: N/A
# originalMethod: Typed
# typeStatus: no type status
# ==================================================
# Processing 7/10: sat_0007_V0574052F_corrected_transcripts.txt
# verbatimCollectors: F. G. OVERLAET
# collectedBy: F G Overlaet
# secondaryCollectors: N/A
# recordNumber: 1023-4
# verbatimEventDate: N/A
# minimumEventDate: sd
# maximumEventDate: N/A
# verbatimIdentification: Scirpus
# latestScientificName: Scirpus
# identifiedBy: N/A
# verbatimDateIdentified: N/A
# associatedTaxa: N/A
# country: Belgian Congo
# firstPoliticalUnit: N/A
# secondPoliticalUnit: N/A
# municipality: N/A
# verbatimLocality: N/A
# locality: [precise locality unknown]
# habitat: N/A
# verbatimElevation: N/A
# verbatimCoordinates: N/A
# otherCatalogNumbers: 752378
# originalMethod: Typed
# typeStatus: no type status
# ==================================================
# Processing 8/10: sat_0008_V0577681F_corrected_transcripts.txt
# verbatimCollectors: C.J.P. Seegeler
#
# collectedBy: C J P Seegeler
#
# secondaryCollectors: N/A
#
# recordNumber: 2806
#
# verbatimEventDate: 23 October 1972
#
# minimumEventDate: 1972-10-23
#
# maximumEventDate: N/A
#
# verbatimIdentification: Vernonia abyssinica Sch.Bip.
#
# latestScientificName: Vernonia abyssinica Sch.Bip.
#
# identifiedBy: G J H Amshoff
#
# verbatimDateIdentified: 1982
#
# associatedTaxa: N/A
#
# country: Ethiopia
#
# firstPoliticalUnit: Shewa
#
# secondPoliticalUnit: N/A
#
# municipality: N/A
#
# verbatimLocality: c. 3 km from Metahara, on road to Nazareth. In full sun on lava rock
#
# locality: c. 3 km from Metahara, on road to Nazareth. In full sun on lava rock
#
# habitat: Erect herb, about 90 cm high and 30 cm wide. Stem pale brown, near the top brownish-green. Leaves medium green, beneath paler with pale midrib. Involucre pale green with dark green tops. Florets at opening dark purple, older paler to almost white. Fragrant when fresh. Pollen white. Fruits brownish-black with yellowish white pappus
#
# verbatimElevation: 925m
#
# verbatimCoordinates: c. 8°56' N, 39°55' E
#
# otherCatalogNumbers: 2302803
#
# originalMethod: Typed
#
# typeStatus: no type status
# ==================================================
# Processing 9/10: sat_0009_V0597557F_corrected_transcripts.txt
# verbatimCollectors: N/A
#
# collectedBy: N/A
#
# secondaryCollectors: N/A
#
# recordNumber: 48
#
# verbatimEventDate: 05.08.2003
#
# minimumEventDate: 2003-08-05
#
# maximumEventDate: N/A
#
# verbatimIdentification: Carduus leptacanthus FRES
#
# latestScientificName: Carduus leptacanthus FRES
#
# identifiedBy: N/A
#
# verbatimDateIdentified: N/A
#
# associatedTaxa: N/A
#
# country: N/A
#
# firstPoliticalUnit: Sud-Kivu
#
# secondPoliticalUnit: Kabare
#
# municipality: N/A
#
# verbatimLocality: Musisi
#
# locality: Musisi
#
# habitat: Herbe
#
# verbatimElevation: N/A
#
# verbatimCoordinates: N/A
#
# otherCatalogNumbers: 2257689
#
# originalMethod: Typed
#
# typeStatus: no type status
# ==================================================
# Processing 10/10: sat_0010_V0594376F_corrected_transcripts.txt
# verbatimCollectors: J.M. Fay
#
# collectedBy: J M Fay
#
# secondaryCollectors: N/A
#
# recordNumber: 8017
#
# verbatimEventDate: 25 May 1987
#
# minimumEventDate: 1987-05-25
#
# maximumEventDate: N/A
#
# verbatimIdentification: Burkea africana Hook.
#
# latestScientificName: Burkea africana Hook.
#
# identifiedBy: J M Fay
#
# verbatimDateIdentified: N/A
#
# associatedTaxa: N/A
#
# country: Central African Republic
#
# firstPoliticalUnit: N/A
#
# secondPoliticalUnit: N/A
#
# municipality: N/A
#
# verbatimLocality: Park Manovo-Gounda-St. Floris. vicinity of Camp Koumbala. prec: 1200 mm 08°29'N 21°12'E
#
# locality: Park Manovo-Gounda-St. Floris. vicinity of Camp Koumbala. prec: 1200 mm
#
# habitat: N/A
#
# verbatimElevation: 600 m
#
# verbatimCoordinates: 08°29'N 21°12'E
#
# otherCatalogNumbers: 1999189
#
# originalMethod: Typed
#
# typeStatus: no type status
# ==================================================
# Done in 72.1s
