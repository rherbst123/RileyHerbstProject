# %%
import easyocr
import numpy as np
from PIL import Image
import os
import math

# %%
#This is the most stable EasyOCR processing 
#This is the pipeline we will use for production

reader = easyocr.Reader(['en'])
base_folder = r"C:\\Users\\Riley\\Documents\\GitHub\\RileyHerbstProject\\DEMO\\Segmented_Images_Cleaned"
# Out:
# C:\Users\Riley\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\cuda\__init__.py:235: UserWarning:
# NVIDIA GeForce RTX 5070 Ti with CUDA capability sm_120 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_37 sm_50 sm_60 sm_61 sm_70 sm_75 sm_80 sm_86 sm_90 compute_37.
# If you want to use the NVIDIA GeForce RTX 5070 Ti GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(

# %%
def create_collage(image_paths, output_path, max_width=2000, background_color=(0, 0, 0)):
    images = []

    # Load all images
    for image_path in image_paths:
        try:
            img = Image.open(image_path).convert('RGB')
            images.append(img)
        except Exception as e:
            print(f"Error processing image {image_path} for collage: {e}")
            continue

    if not images:
        print("No images to create collage.")
        return

    # Sort images by height (optional)
    images.sort(key=lambda img: img.size[1])

    # Initialize variables for arranging images
    rows = []
    current_row = []
    current_width = 0
    max_row_height = 0

    for img in images:
        img_width, img_height = img.size
        if current_width + img_width <= max_width:
            current_row.append(img)
            current_width += img_width
            max_row_height = max(max_row_height, img_height)
        else:
            rows.append((current_row, max_row_height))
            current_row = [img]
            current_width = img_width
            max_row_height = img_height

    if current_row:
        rows.append((current_row, max_row_height))

    collage_width = max_width
    collage_height = sum(height for (_, height) in rows)


    collage_image = Image.new('RGB', (collage_width, collage_height), color=background_color)


    y_offset = 0
    for row_images, row_height in rows:
        x_offset = 0
        for img in row_images:
            collage_image.paste(img, (x_offset, y_offset))
            x_offset += img.size[0]
        y_offset += row_height

    collage_image = collage_image.crop(collage_image.getbbox())  # Crop to content
    collage_image.save(output_path)
    print(f"Collage saved to {output_path}")

# Create the 'final collages' folder
final_collages_folder = os.path.join(base_folder, 'final collages')
os.makedirs(final_collages_folder, exist_ok=True)



# image size weeeeeeeding out
for root, dirs, files in os.walk(base_folder):
    # Exclude 'final collages' from processing
    if 'final collages' in dirs:
        print(f"Processing folder: {root}")
        #dirs.remove('final collages')
    #print(f"Processing folder: {root}")  # Print the current folder being processed

    kept_images = []  # List to store paths of images that are kept

    for filename in files:
        file_path = os.path.join(root, filename)
        
        # Check if the file is the segmentation_visualization or the collage itself, and skip it
        if 'segmentation_visualization' in filename or 'collage' in filename:
            print(f"Skipping {filename}")
            continue

        try:
            # Open the image file
            with Image.open(file_path) as img:
                width, height = img.size
                img_np = np.array(img)


            result = reader.readtext(img_np, detail=0)
            text = ' '.join(result)
                
        
            words = text.strip().split()
            word_count = len(words)
             
                
            if word_count < 3:
                print(f"Only {word_count} words detected in {filename}. Deleting...")
                os.remove(file_path)
                continue

          
            if width > 800 and height > 1500:
                print(f"Image {filename} has a resolution of {width}x{height}. Deleting...")
                os.remove(file_path)
                continue

      
            if height >= 4.7 * width:
                print(f"Image {filename} has a height {height} that is 4 times as large as its width {width}. Deleting...")
                os.remove(file_path)
                continue
            
            
            if width >= 4.7 * height:
                print(f"Image {filename} has a height {width} that is 4 times as large as its width {height}. Deleting...")
                os.remove(file_path)
                continue

            else:
                print(f"{word_count} words detected in {filename}. Keeping the image.")
                kept_images.append(file_path)
                        
        except Exception as e:
            print(f"Error processing {filename}: {e}")

    
    if kept_images:
        folder_name = os.path.basename(root)
        collage_output_path = os.path.join(final_collages_folder, f"{folder_name}_collage.png")
        create_collage(kept_images, collage_output_path)
# Out:
# Processing folder: C:\\Users\\Riley\\Documents\\GitHub\\RileyHerbstProject\\DEMO\\Segmented_Images_Cleaned
# 3 words detected in mask_1.png. Keeping the image.
# Only 0 words detected in mask_10.png. Deleting...
# Only 0 words detected in mask_11.png. Deleting...
# Only 0 words detected in mask_12.png. Deleting...
# Only 0 words detected in mask_13.png. Deleting...
# Only 0 words detected in mask_14.png. Deleting...
# Only 0 words detected in mask_15.png. Deleting...
# Only 0 words detected in mask_16.png. Deleting...
# Only 0 words detected in mask_17.png. Deleting...
# Only 0 words detected in mask_18.png. Deleting...
# Only 0 words detected in mask_19.png. Deleting...
# Image mask_2.png has a height 821 that is 4 times as large as its width 110. Deleting...
# Only 0 words detected in mask_20.png. Deleting...
# Only 0 words detected in mask_21.png. Deleting...
# Only 0 words detected in mask_22.png. Deleting...
# Only 0 words detected in mask_23.png. Deleting...
# Only 0 words detected in mask_24.png. Deleting...
# Only 0 words detected in mask_25.png. Deleting...
# Only 0 words detected in mask_26.png. Deleting...
# Only 0 words detected in mask_27.png. Deleting...
# Only 0 words detected in mask_28.png. Deleting...
# Only 0 words detected in mask_29.png. Deleting...
# Image mask_3.png has a height 536 that is 4 times as large as its width 104. Deleting...
# Only 0 words detected in mask_30.png. Deleting...
# Only 0 words detected in mask_31.png. Deleting...
# Only 0 words detected in mask_32.png. Deleting...
# Only 0 words detected in mask_33.png. Deleting...
# Only 0 words detected in mask_34.png. Deleting...
# Only 0 words detected in mask_35.png. Deleting...
# Only 0 words detected in mask_36.png. Deleting...
# Only 0 words detected in mask_37.png. Deleting...
# Image mask_38.png has a height 441 that is 4 times as large as its width 78. Deleting...
# Only 0 words detected in mask_39.png. Deleting...
# 3 words detected in mask_4.png. Keeping the image.
# Only 0 words detected in mask_40.png. Deleting...
# Only 0 words detected in mask_41.png. Deleting...
# Only 0 words detected in mask_42.png. Deleting...
# Only 0 words detected in mask_43.png. Deleting...
# Only 0 words detected in mask_44.png. Deleting...
# Only 0 words detected in mask_45.png. Deleting...
# Only 0 words detected in mask_46.png. Deleting...
# Only 0 words detected in mask_47.png. Deleting...
# Only 0 words detected in mask_48.png. Deleting...
# Only 0 words detected in mask_49.png. Deleting...
# 41 words detected in mask_5.png. Keeping the image.
# 8 words detected in mask_6.png. Keeping the image.
# Only 0 words detected in mask_7.png. Deleting...
# Only 0 words detected in mask_8.png. Deleting...
# Only 0 words detected in mask_9.png. Deleting...
# Skipping sat_0001_V0573776F_segmentation_visualization.png as it's not a target image.
# Collage saved to C:\\Users\\Riley\\Documents\\GitHub\\RileyHerbstProject\\DEMO\\Segmented_Images_Cleaned\final collages\sat_0001_V0573776F_collage.png
# Only 0 words detected in mask_1.png. Deleting...
# Only 0 words detected in mask_10.png. Deleting...
# Only 0 words detected in mask_11.png. Deleting...
# Only 0 words detected in mask_12.png. Deleting...
# Only 0 words detected in mask_13.png. Deleting...
# Image mask_14.png has a height 825 that is 4 times as large as its width 121. Deleting...
# Only 0 words detected in mask_15.png. Deleting...
# Only 0 words detected in mask_16.png. Deleting...
# Only 0 words detected in mask_17.png. Deleting...
# Only 0 words detected in mask_18.png. Deleting...
# Only 0 words detected in mask_19.png. Deleting...
# Only 1 words detected in mask_2.png. Deleting...
# Only 0 words detected in mask_20.png. Deleting...
# Only 0 words detected in mask_21.png. Deleting...
# Only 0 words detected in mask_22.png. Deleting...
# Only 0 words detected in mask_23.png. Deleting...
# Only 0 words detected in mask_24.png. Deleting...
# Only 0 words detected in mask_25.png. Deleting...
# Only 0 words detected in mask_26.png. Deleting...
# Only 0 words detected in mask_27.png. Deleting...
# Only 0 words detected in mask_28.png. Deleting...
# Only 0 words detected in mask_29.png. Deleting...
# Only 0 words detected in mask_3.png. Deleting...
# Only 0 words detected in mask_30.png. Deleting...
# Only 0 words detected in mask_31.png. Deleting...
# Only 0 words detected in mask_32.png. Deleting...
# Only 0 words detected in mask_33.png. Deleting...
# Only 0 words detected in mask_34.png. Deleting...
# Only 0 words detected in mask_35.png. Deleting...
# Only 0 words detected in mask_36.png. Deleting...
# Only 0 words detected in mask_37.png. Deleting...
# Only 0 words detected in mask_38.png. Deleting...
# Only 0 words detected in mask_39.png. Deleting...
# Image mask_4.png has a height 536 that is 4 times as large as its width 108. Deleting...
# Only 0 words detected in mask_40.png. Deleting...
# Only 0 words detected in mask_41.png. Deleting...
# Only 0 words detected in mask_42.png. Deleting...
# Only 0 words detected in mask_43.png. Deleting...
# Only 0 words detected in mask_44.png. Deleting...
# Only 0 words detected in mask_45.png. Deleting...
# Only 0 words detected in mask_46.png. Deleting...
# Only 0 words detected in mask_47.png. Deleting...
# Only 0 words detected in mask_48.png. Deleting...
# Only 0 words detected in mask_49.png. Deleting...
# Only 0 words detected in mask_5.png. Deleting...
# Only 0 words detected in mask_50.png. Deleting...
# Only 0 words detected in mask_51.png. Deleting...
# Only 0 words detected in mask_52.png. Deleting...
# Only 0 words detected in mask_53.png. Deleting...
# Only 0 words detected in mask_54.png. Deleting...
# Only 1 words detected in mask_55.png. Deleting...
# Only 0 words detected in mask_56.png. Deleting...
# Only 0 words detected in mask_57.png. Deleting...
# Only 0 words detected in mask_58.png. Deleting...
# Only 0 words detected in mask_59.png. Deleting...
# 6 words detected in mask_6.png. Keeping the image.
# Only 1 words detected in mask_60.png. Deleting...
# Only 0 words detected in mask_61.png. Deleting...
# Only 0 words detected in mask_62.png. Deleting...
# Only 0 words detected in mask_63.png. Deleting...
# Only 0 words detected in mask_64.png. Deleting...
# 3 words detected in mask_7.png. Keeping the image.
# 7 words detected in mask_8.png. Keeping the image.
# 13 words detected in mask_9.png. Keeping the image.
# Skipping sat_0002_V0576008F_segmentation_visualization.png as it's not a target image.
# Collage saved to C:\\Users\\Riley\\Documents\\GitHub\\RileyHerbstProject\\DEMO\\Segmented_Images_Cleaned\final collages\sat_0002_V0576008F_collage.png
# Only 0 words detected in mask_1.png. Deleting...
# Only 0 words detected in mask_10.png. Deleting...
# Image mask_11.png has a height 821 that is 4 times as large as its width 123. Deleting...
# Only 0 words detected in mask_12.png. Deleting...
# Only 0 words detected in mask_13.png. Deleting...
# Only 0 words detected in mask_14.png. Deleting...
# Only 0 words detected in mask_15.png. Deleting...
# Only 0 words detected in mask_16.png. Deleting...
# Only 0 words detected in mask_17.png. Deleting...
# Only 0 words detected in mask_18.png. Deleting...
# Only 0 words detected in mask_19.png. Deleting...
# Only 0 words detected in mask_2.png. Deleting...
# Only 0 words detected in mask_20.png. Deleting...
# Only 0 words detected in mask_21.png. Deleting...
# Only 0 words detected in mask_22.png. Deleting...
# Only 0 words detected in mask_23.png. Deleting...
# Only 0 words detected in mask_24.png. Deleting...
# Only 0 words detected in mask_25.png. Deleting...
# Only 0 words detected in mask_26.png. Deleting...
# Only 0 words detected in mask_27.png. Deleting...
# Only 1 words detected in mask_28.png. Deleting...
# Only 0 words detected in mask_29.png. Deleting...
# 3 words detected in mask_3.png. Keeping the image.
# Only 0 words detected in mask_30.png. Deleting...
# Only 0 words detected in mask_31.png. Deleting...
# Only 0 words detected in mask_32.png. Deleting...
# Only 0 words detected in mask_33.png. Deleting...
# Only 0 words detected in mask_34.png. Deleting...
# Only 0 words detected in mask_35.png. Deleting...
# Only 0 words detected in mask_36.png. Deleting...
# Only 0 words detected in mask_37.png. Deleting...
# Only 0 words detected in mask_38.png. Deleting...
# Only 1 words detected in mask_39.png. Deleting...
# Image mask_4.png has a height 537 that is 4 times as large as its width 106. Deleting...
# Only 1 words detected in mask_40.png. Deleting...
# Only 1 words detected in mask_41.png. Deleting...
# Only 0 words detected in mask_42.png. Deleting...
# Only 0 words detected in mask_43.png. Deleting...
# Only 0 words detected in mask_44.png. Deleting...
# Only 0 words detected in mask_45.png. Deleting...
# Only 0 words detected in mask_46.png. Deleting...
# Only 0 words detected in mask_47.png. Deleting...
# Only 0 words detected in mask_48.png. Deleting...
# Only 0 words detected in mask_49.png. Deleting...
# Only 0 words detected in mask_5.png. Deleting...
# Only 0 words detected in mask_50.png. Deleting...
# Only 0 words detected in mask_51.png. Deleting...
# Only 0 words detected in mask_52.png. Deleting...
# Only 0 words detected in mask_53.png. Deleting...
# Only 0 words detected in mask_54.png. Deleting...
# Only 0 words detected in mask_55.png. Deleting...
# Only 0 words detected in mask_56.png. Deleting...
# Only 0 words detected in mask_57.png. Deleting...
# Only 0 words detected in mask_58.png. Deleting...
# Only 0 words detected in mask_59.png. Deleting...
# 3 words detected in mask_6.png. Keeping the image.
# Only 0 words detected in mask_60.png. Deleting...
# Only 0 words detected in mask_61.png. Deleting...
# Only 0 words detected in mask_7.png. Deleting...
# 80 words detected in mask_8.png. Keeping the image.
# Only 0 words detected in mask_9.png. Deleting...
# Skipping sat_0003_V0576279F_segmentation_visualization.png as it's not a target image.
# Collage saved to C:\\Users\\Riley\\Documents\\GitHub\\RileyHerbstProject\\DEMO\\Segmented_Images_Cleaned\final collages\sat_0003_V0576279F_collage.png
# 3 words detected in mask_1.png. Keeping the image.
# Only 0 words detected in mask_10.png. Deleting...
# Image mask_11.png has a height 824 that is 4 times as large as its width 122. Deleting...
# Only 0 words detected in mask_12.png. Deleting...
# Only 0 words detected in mask_13.png. Deleting...
# Only 0 words detected in mask_14.png. Deleting...
# Only 0 words detected in mask_15.png. Deleting...
# Only 0 words detected in mask_16.png. Deleting...
# Only 0 words detected in mask_17.png. Deleting...
# Only 0 words detected in mask_18.png. Deleting...
# Only 0 words detected in mask_19.png. Deleting...
# Only 0 words detected in mask_2.png. Deleting...
# Only 0 words detected in mask_20.png. Deleting...
# Only 0 words detected in mask_21.png. Deleting...
# Only 0 words detected in mask_22.png. Deleting...
# Only 0 words detected in mask_23.png. Deleting...
# Only 0 words detected in mask_24.png. Deleting...
# Only 0 words detected in mask_25.png. Deleting...
# Only 0 words detected in mask_26.png. Deleting...
# Only 0 words detected in mask_27.png. Deleting...
# Only 0 words detected in mask_28.png. Deleting...
# Only 0 words detected in mask_29.png. Deleting...
# Image mask_3.png has a height 536 that is 4 times as large as its width 106. Deleting...
# Only 0 words detected in mask_30.png. Deleting...
# Only 0 words detected in mask_31.png. Deleting...
# Only 0 words detected in mask_32.png. Deleting...
# Only 0 words detected in mask_33.png. Deleting...
# Only 0 words detected in mask_34.png. Deleting...
# Only 0 words detected in mask_35.png. Deleting...
# Only 0 words detected in mask_36.png. Deleting...
# Only 1 words detected in mask_37.png. Deleting...
# Only 0 words detected in mask_38.png. Deleting...
# Only 0 words detected in mask_39.png. Deleting...
# Only 0 words detected in mask_4.png. Deleting...
# Only 0 words detected in mask_40.png. Deleting...
# Only 0 words detected in mask_41.png. Deleting...
# Only 2 words detected in mask_42.png. Deleting...
# Only 0 words detected in mask_43.png. Deleting...
# Only 0 words detected in mask_44.png. Deleting...
# Only 0 words detected in mask_45.png. Deleting...
# Only 0 words detected in mask_46.png. Deleting...
# Only 0 words detected in mask_47.png. Deleting...
# Only 0 words detected in mask_48.png. Deleting...
# Only 0 words detected in mask_49.png. Deleting...
# Only 0 words detected in mask_5.png. Deleting...
# Only 0 words detected in mask_50.png. Deleting...
# Only 0 words detected in mask_51.png. Deleting...
# Only 0 words detected in mask_52.png. Deleting...
# Only 0 words detected in mask_53.png. Deleting...
# Only 0 words detected in mask_54.png. Deleting...
# Only 0 words detected in mask_55.png. Deleting...
# Only 0 words detected in mask_56.png. Deleting...
# Only 0 words detected in mask_57.png. Deleting...
# Only 1 words detected in mask_58.png. Deleting...
# 11 words detected in mask_59.png. Keeping the image.
# Only 0 words detected in mask_6.png. Deleting...
# Only 1 words detected in mask_60.png. Deleting...
# Only 0 words detected in mask_61.png. Deleting...
# Only 0 words detected in mask_62.png. Deleting...
# Only 0 words detected in mask_63.png. Deleting...
# Only 0 words detected in mask_64.png. Deleting...
# Only 0 words detected in mask_65.png. Deleting...
# Only 0 words detected in mask_66.png. Deleting...
# Only 0 words detected in mask_67.png. Deleting...
# Only 1 words detected in mask_68.png. Deleting...
# Only 0 words detected in mask_69.png. Deleting...
# Only 0 words detected in mask_7.png. Deleting...
# Only 0 words detected in mask_70.png. Deleting...
# Only 0 words detected in mask_71.png. Deleting...
# Only 1 words detected in mask_72.png. Deleting...
# Only 0 words detected in mask_73.png. Deleting...
# Only 0 words detected in mask_74.png. Deleting...
# Only 0 words detected in mask_75.png. Deleting...
# Only 0 words detected in mask_76.png. Deleting...
# 80 words detected in mask_8.png. Keeping the image.
# Only 0 words detected in mask_9.png. Deleting...
# Skipping sat_0004_V0577013F_segmentation_visualization.png as it's not a target image.
# Collage saved to C:\\Users\\Riley\\Documents\\GitHub\\RileyHerbstProject\\DEMO\\Segmented_Images_Cleaned\final collages\sat_0004_V0577013F_collage.png
# 3 words detected in mask_1.png. Keeping the image.
# Only 0 words detected in mask_10.png. Deleting...
# Only 0 words detected in mask_11.png. Deleting...
# Only 0 words detected in mask_12.png. Deleting...
# Only 0 words detected in mask_13.png. Deleting...
# Only 0 words detected in mask_14.png. Deleting...
# Only 0 words detected in mask_15.png. Deleting...
# Only 0 words detected in mask_16.png. Deleting...
# Only 0 words detected in mask_17.png. Deleting...
# Only 0 words detected in mask_18.png. Deleting...
# Only 0 words detected in mask_19.png. Deleting...
# Image mask_2.png has a height 823 that is 4 times as large as its width 124. Deleting...
# Only 0 words detected in mask_20.png. Deleting...
# Only 0 words detected in mask_21.png. Deleting...
# Only 0 words detected in mask_22.png. Deleting...
# Only 0 words detected in mask_23.png. Deleting...
# Only 0 words detected in mask_24.png. Deleting...
# Only 0 words detected in mask_25.png. Deleting...
# Only 0 words detected in mask_26.png. Deleting...
# Only 0 words detected in mask_27.png. Deleting...
# Only 0 words detected in mask_28.png. Deleting...
# Only 0 words detected in mask_29.png. Deleting...
# Only 0 words detected in mask_3.png. Deleting...
# Only 0 words detected in mask_30.png. Deleting...
# Only 0 words detected in mask_31.png. Deleting...
# Only 0 words detected in mask_32.png. Deleting...
# Only 0 words detected in mask_33.png. Deleting...
# Only 0 words detected in mask_34.png. Deleting...
# Only 0 words detected in mask_35.png. Deleting...
# Only 0 words detected in mask_36.png. Deleting...
# Only 0 words detected in mask_37.png. Deleting...
# Only 0 words detected in mask_38.png. Deleting...
# Only 0 words detected in mask_39.png. Deleting...
# Only 1 words detected in mask_4.png. Deleting...
# Only 1 words detected in mask_40.png. Deleting...
# Only 0 words detected in mask_41.png. Deleting...
# Only 0 words detected in mask_42.png. Deleting...
# Only 0 words detected in mask_43.png. Deleting...
# Only 0 words detected in mask_44.png. Deleting...
# Only 0 words detected in mask_45.png. Deleting...
# Only 0 words detected in mask_46.png. Deleting...
# Only 0 words detected in mask_47.png. Deleting...
# Only 0 words detected in mask_48.png. Deleting...
# Only 0 words detected in mask_49.png. Deleting...
# 40 words detected in mask_5.png. Keeping the image.
# Only 0 words detected in mask_50.png. Deleting...
# Only 0 words detected in mask_51.png. Deleting...
# Only 0 words detected in mask_52.png. Deleting...
# Only 0 words detected in mask_53.png. Deleting...
# Only 0 words detected in mask_54.png. Deleting...
# Only 0 words detected in mask_55.png. Deleting...
# Only 0 words detected in mask_56.png. Deleting...
# Only 0 words detected in mask_57.png. Deleting...
# Only 0 words detected in mask_58.png. Deleting...
# Only 0 words detected in mask_59.png. Deleting...
# Image mask_6.png has a height 539 that is 4 times as large as its width 107. Deleting...
# Only 1 words detected in mask_60.png. Deleting...
# Only 0 words detected in mask_61.png. Deleting...
# 37 words detected in mask_62.png. Keeping the image.
# Only 0 words detected in mask_63.png. Deleting...
# Only 0 words detected in mask_64.png. Deleting...
# Only 0 words detected in mask_65.png. Deleting...
# Only 0 words detected in mask_66.png. Deleting...
# Only 0 words detected in mask_67.png. Deleting...
# Only 0 words detected in mask_7.png. Deleting...
# Only 0 words detected in mask_8.png. Deleting...
# Only 0 words detected in mask_9.png. Deleting...
# Skipping sat_0005_V0577892F_segmentation_visualization.png as it's not a target image.
# Collage saved to C:\\Users\\Riley\\Documents\\GitHub\\RileyHerbstProject\\DEMO\\Segmented_Images_Cleaned\final collages\sat_0005_V0577892F_collage.png
# 3 words detected in mask_1.png. Keeping the image.
# Only 0 words detected in mask_10.png. Deleting...
# Only 0 words detected in mask_11.png. Deleting...
# Only 0 words detected in mask_12.png. Deleting...
# Only 0 words detected in mask_13.png. Deleting...
# Only 0 words detected in mask_14.png. Deleting...
# Only 0 words detected in mask_15.png. Deleting...
# Only 0 words detected in mask_16.png. Deleting...
# Only 0 words detected in mask_17.png. Deleting...
# Only 0 words detected in mask_18.png. Deleting...
# Only 0 words detected in mask_19.png. Deleting...
# Image mask_2.png has a height 536 that is 4 times as large as its width 106. Deleting...
# Only 0 words detected in mask_20.png. Deleting...
# Only 0 words detected in mask_21.png. Deleting...
# Only 0 words detected in mask_22.png. Deleting...
# Only 0 words detected in mask_23.png. Deleting...
# Only 0 words detected in mask_24.png. Deleting...
# Only 1 words detected in mask_25.png. Deleting...
# Only 0 words detected in mask_26.png. Deleting...
# Only 1 words detected in mask_27.png. Deleting...
# Only 0 words detected in mask_28.png. Deleting...
# Only 0 words detected in mask_29.png. Deleting...
# Only 0 words detected in mask_3.png. Deleting...
# Only 1 words detected in mask_30.png. Deleting...
# Only 0 words detected in mask_31.png. Deleting...
# Only 0 words detected in mask_32.png. Deleting...
# Only 0 words detected in mask_33.png. Deleting...
# Only 0 words detected in mask_34.png. Deleting...
# Only 0 words detected in mask_35.png. Deleting...
# Only 0 words detected in mask_36.png. Deleting...
# Only 0 words detected in mask_37.png. Deleting...
# Only 0 words detected in mask_38.png. Deleting...
# Only 0 words detected in mask_39.png. Deleting...
# Only 0 words detected in mask_4.png. Deleting...
# Only 0 words detected in mask_40.png. Deleting...
# Only 0 words detected in mask_41.png. Deleting...
# Only 0 words detected in mask_42.png. Deleting...
# Only 0 words detected in mask_43.png. Deleting...
# Only 2 words detected in mask_44.png. Deleting...
# Only 1 words detected in mask_45.png. Deleting...
# Only 1 words detected in mask_46.png. Deleting...
# Only 0 words detected in mask_47.png. Deleting...
# Only 1 words detected in mask_48.png. Deleting...
# Only 0 words detected in mask_49.png. Deleting...
# 42 words detected in mask_5.png. Keeping the image.
# Only 0 words detected in mask_50.png. Deleting...
# Only 0 words detected in mask_51.png. Deleting...
# Only 0 words detected in mask_52.png. Deleting...
# Only 0 words detected in mask_53.png. Deleting...
# Only 0 words detected in mask_54.png. Deleting...
# Only 0 words detected in mask_6.png. Deleting...
# Image mask_7.png has a height 822 that is 4 times as large as its width 121. Deleting...
# Only 0 words detected in mask_8.png. Deleting...
# Only 0 words detected in mask_9.png. Deleting...
# Skipping sat_0006_V0578553F_segmentation_visualization.png as it's not a target image.
# Collage saved to C:\\Users\\Riley\\Documents\\GitHub\\RileyHerbstProject\\DEMO\\Segmented_Images_Cleaned\final collages\sat_0006_V0578553F_collage.png
# Only 0 words detected in mask_1.png. Deleting...
# Only 0 words detected in mask_10.png. Deleting...
# Only 0 words detected in mask_11.png. Deleting...
# Only 0 words detected in mask_12.png. Deleting...
# Only 0 words detected in mask_13.png. Deleting...
# Only 0 words detected in mask_14.png. Deleting...
# Only 0 words detected in mask_15.png. Deleting...
# Only 0 words detected in mask_16.png. Deleting...
# Only 0 words detected in mask_17.png. Deleting...
# Only 0 words detected in mask_18.png. Deleting...
# Only 0 words detected in mask_19.png. Deleting...
# Only 0 words detected in mask_2.png. Deleting...
# Only 0 words detected in mask_20.png. Deleting...
# Only 0 words detected in mask_21.png. Deleting...
# Only 0 words detected in mask_22.png. Deleting...
# Only 0 words detected in mask_23.png. Deleting...
# Only 0 words detected in mask_24.png. Deleting...
# Only 0 words detected in mask_25.png. Deleting...
# Only 0 words detected in mask_26.png. Deleting...
# Only 0 words detected in mask_27.png. Deleting...
# Only 0 words detected in mask_28.png. Deleting...
# Only 0 words detected in mask_29.png. Deleting...
# Only 0 words detected in mask_3.png. Deleting...
# Only 0 words detected in mask_30.png. Deleting...
# Only 0 words detected in mask_31.png. Deleting...
# Only 0 words detected in mask_32.png. Deleting...
# Only 0 words detected in mask_33.png. Deleting...
# Only 0 words detected in mask_34.png. Deleting...
# Only 0 words detected in mask_35.png. Deleting...
# Only 0 words detected in mask_36.png. Deleting...
# Only 0 words detected in mask_37.png. Deleting...
# Only 0 words detected in mask_38.png. Deleting...
# Only 0 words detected in mask_39.png. Deleting...
# Only 1 words detected in mask_4.png. Deleting...
# Only 0 words detected in mask_40.png. Deleting...
# Only 0 words detected in mask_41.png. Deleting...
# Only 0 words detected in mask_42.png. Deleting...
# Only 0 words detected in mask_43.png. Deleting...
# Only 0 words detected in mask_44.png. Deleting...
# Only 0 words detected in mask_45.png. Deleting...
# Only 0 words detected in mask_46.png. Deleting...
# Only 0 words detected in mask_47.png. Deleting...
# Only 0 words detected in mask_48.png. Deleting...
# Only 0 words detected in mask_49.png. Deleting...
# Image mask_5.png has a height 540 that is 4 times as large as its width 107. Deleting...
# Only 0 words detected in mask_50.png. Deleting...
# Only 0 words detected in mask_51.png. Deleting...
# Only 0 words detected in mask_52.png. Deleting...
# Only 0 words detected in mask_53.png. Deleting...
# Only 0 words detected in mask_54.png. Deleting...
# Only 0 words detected in mask_55.png. Deleting...
# Only 0 words detected in mask_56.png. Deleting...
# Only 0 words detected in mask_57.png. Deleting...
# Only 0 words detected in mask_58.png. Deleting...
# Only 0 words detected in mask_59.png. Deleting...
# 3 words detected in mask_6.png. Keeping the image.
# Only 0 words detected in mask_60.png. Deleting...
# Only 0 words detected in mask_61.png. Deleting...
# Only 0 words detected in mask_62.png. Deleting...
# Only 0 words detected in mask_63.png. Deleting...
# Only 0 words detected in mask_64.png. Deleting...
# Only 0 words detected in mask_65.png. Deleting...
# Only 0 words detected in mask_66.png. Deleting...
# Only 0 words detected in mask_67.png. Deleting...
# Only 0 words detected in mask_68.png. Deleting...
# Only 0 words detected in mask_69.png. Deleting...
# 10 words detected in mask_7.png. Keeping the image.
# Only 0 words detected in mask_70.png. Deleting...
# Only 0 words detected in mask_71.png. Deleting...
# Only 0 words detected in mask_72.png. Deleting...
# Only 0 words detected in mask_73.png. Deleting...
# Only 0 words detected in mask_74.png. Deleting...
# Image mask_75.png has a height 304 that is 4 times as large as its width 59. Deleting...
# Only 0 words detected in mask_76.png. Deleting...
# Only 0 words detected in mask_77.png. Deleting...
# Only 0 words detected in mask_78.png. Deleting...
# Only 0 words detected in mask_79.png. Deleting...
# Only 0 words detected in mask_8.png. Deleting...
# Only 0 words detected in mask_80.png. Deleting...
# Only 0 words detected in mask_81.png. Deleting...
# Only 0 words detected in mask_82.png. Deleting...
# Image mask_9.png has a height 838 that is 4 times as large as its width 120. Deleting...
# Skipping sat_0007_V0574052F_segmentation_visualization.png as it's not a target image.
# Collage saved to C:\\Users\\Riley\\Documents\\GitHub\\RileyHerbstProject\\DEMO\\Segmented_Images_Cleaned\final collages\sat_0007_V0574052F_collage.png
# 3 words detected in mask_1.png. Keeping the image.
# Image mask_10.png has a height 557 that is 4 times as large as its width 109. Deleting...
# Only 0 words detected in mask_100.png. Deleting...
# Only 0 words detected in mask_101.png. Deleting...
# Only 0 words detected in mask_11.png. Deleting...
# Only 0 words detected in mask_12.png. Deleting...
# Only 0 words detected in mask_13.png. Deleting...
# Only 0 words detected in mask_14.png. Deleting...
# Only 0 words detected in mask_15.png. Deleting...
# Image mask_16.png has a height 826 that is 4 times as large as its width 128. Deleting...
# Only 0 words detected in mask_17.png. Deleting...
# Only 0 words detected in mask_18.png. Deleting...
# Only 0 words detected in mask_19.png. Deleting...
# Only 0 words detected in mask_2.png. Deleting...
# Only 0 words detected in mask_20.png. Deleting...
# Only 0 words detected in mask_21.png. Deleting...
# Only 0 words detected in mask_22.png. Deleting...
# Only 0 words detected in mask_23.png. Deleting...
# Only 0 words detected in mask_24.png. Deleting...
# Only 0 words detected in mask_25.png. Deleting...
# Only 0 words detected in mask_26.png. Deleting...
# Only 0 words detected in mask_27.png. Deleting...
# Only 0 words detected in mask_28.png. Deleting...
# Only 0 words detected in mask_29.png. Deleting...
# Only 0 words detected in mask_3.png. Deleting...
# Only 0 words detected in mask_30.png. Deleting...
# Only 0 words detected in mask_31.png. Deleting...
# Only 0 words detected in mask_32.png. Deleting...
# Only 0 words detected in mask_33.png. Deleting...
# Only 0 words detected in mask_34.png. Deleting...
# Only 0 words detected in mask_35.png. Deleting...
# Only 0 words detected in mask_36.png. Deleting...
# Only 0 words detected in mask_37.png. Deleting...
# Only 0 words detected in mask_38.png. Deleting...
# Only 0 words detected in mask_39.png. Deleting...
# Only 0 words detected in mask_4.png. Deleting...
# Only 0 words detected in mask_40.png. Deleting...
# Only 0 words detected in mask_41.png. Deleting...
# Only 0 words detected in mask_42.png. Deleting...
# Only 0 words detected in mask_43.png. Deleting...
# Only 0 words detected in mask_44.png. Deleting...
# Only 0 words detected in mask_45.png. Deleting...
# Only 0 words detected in mask_46.png. Deleting...
# Only 0 words detected in mask_47.png. Deleting...
# Only 0 words detected in mask_48.png. Deleting...
# Only 0 words detected in mask_49.png. Deleting...
# Only 0 words detected in mask_5.png. Deleting...
# Only 0 words detected in mask_50.png. Deleting...
# Only 0 words detected in mask_51.png. Deleting...
# Only 0 words detected in mask_52.png. Deleting...
# Only 1 words detected in mask_53.png. Deleting...
# Only 0 words detected in mask_54.png. Deleting...
# Only 1 words detected in mask_55.png. Deleting...
# Only 0 words detected in mask_56.png. Deleting...
# Only 1 words detected in mask_57.png. Deleting...
# Only 0 words detected in mask_58.png. Deleting...
# Only 0 words detected in mask_59.png. Deleting...
# Only 0 words detected in mask_6.png. Deleting...
# Only 0 words detected in mask_60.png. Deleting...
# Only 0 words detected in mask_61.png. Deleting...
# Only 0 words detected in mask_62.png. Deleting...
# Only 0 words detected in mask_63.png. Deleting...
# Only 0 words detected in mask_64.png. Deleting...
# Only 0 words detected in mask_65.png. Deleting...
# Only 0 words detected in mask_66.png. Deleting...
# Only 1 words detected in mask_67.png. Deleting...
# Only 0 words detected in mask_68.png. Deleting...
# Only 0 words detected in mask_69.png. Deleting...
# Only 2 words detected in mask_7.png. Deleting...
# Only 0 words detected in mask_70.png. Deleting...
# Only 0 words detected in mask_71.png. Deleting...
# Only 0 words detected in mask_72.png. Deleting...
# Only 0 words detected in mask_73.png. Deleting...
# Only 0 words detected in mask_74.png. Deleting...
# Only 0 words detected in mask_75.png. Deleting...
# Only 0 words detected in mask_76.png. Deleting...
# Only 0 words detected in mask_77.png. Deleting...
# Only 0 words detected in mask_78.png. Deleting...
# Only 0 words detected in mask_79.png. Deleting...
# 99 words detected in mask_8.png. Keeping the image.
# Only 0 words detected in mask_80.png. Deleting...
# Only 0 words detected in mask_81.png. Deleting...
# Only 0 words detected in mask_82.png. Deleting...
# Only 0 words detected in mask_83.png. Deleting...
# Only 0 words detected in mask_84.png. Deleting...
# Only 0 words detected in mask_85.png. Deleting...
# Only 0 words detected in mask_86.png. Deleting...
# Only 0 words detected in mask_87.png. Deleting...
# Only 0 words detected in mask_88.png. Deleting...
# Only 0 words detected in mask_89.png. Deleting...
# Only 0 words detected in mask_9.png. Deleting...
# Only 0 words detected in mask_90.png. Deleting...
# Only 0 words detected in mask_91.png. Deleting...
# Only 0 words detected in mask_92.png. Deleting...
# Only 0 words detected in mask_93.png. Deleting...
# Only 0 words detected in mask_94.png. Deleting...
# Only 0 words detected in mask_95.png. Deleting...
# Only 0 words detected in mask_96.png. Deleting...
# Only 0 words detected in mask_97.png. Deleting...
# Image mask_98.png has a resolution of 1456x2087. Deleting...
# Only 0 words detected in mask_99.png. Deleting...
# Skipping sat_0008_V0577681F_segmentation_visualization.png as it's not a target image.
# Collage saved to C:\\Users\\Riley\\Documents\\GitHub\\RileyHerbstProject\\DEMO\\Segmented_Images_Cleaned\final collages\sat_0008_V0577681F_collage.png
# Only 1 words detected in mask_1.png. Deleting...
# Only 0 words detected in mask_10.png. Deleting...
# Only 0 words detected in mask_11.png. Deleting...
# Only 0 words detected in mask_12.png. Deleting...
# Only 0 words detected in mask_13.png. Deleting...
# Image mask_14.png has a height 548 that is 4 times as large as its width 108. Deleting...
# Only 0 words detected in mask_15.png. Deleting...
# Only 0 words detected in mask_16.png. Deleting...
# Only 0 words detected in mask_17.png. Deleting...
# Only 0 words detected in mask_18.png. Deleting...
# Only 0 words detected in mask_19.png. Deleting...
# Only 0 words detected in mask_2.png. Deleting...
# Only 0 words detected in mask_20.png. Deleting...
# Only 0 words detected in mask_21.png. Deleting...
# Only 0 words detected in mask_22.png. Deleting...
# Only 0 words detected in mask_23.png. Deleting...
# Only 0 words detected in mask_24.png. Deleting...
# Only 0 words detected in mask_25.png. Deleting...
# Only 0 words detected in mask_26.png. Deleting...
# Only 0 words detected in mask_27.png. Deleting...
# Only 0 words detected in mask_28.png. Deleting...
# Only 0 words detected in mask_29.png. Deleting...
# Only 1 words detected in mask_3.png. Deleting...
# Only 0 words detected in mask_30.png. Deleting...
# Only 0 words detected in mask_31.png. Deleting...
# Only 0 words detected in mask_32.png. Deleting...
# Only 0 words detected in mask_33.png. Deleting...
# Only 1 words detected in mask_34.png. Deleting...
# Only 1 words detected in mask_35.png. Deleting...
# Only 1 words detected in mask_36.png. Deleting...
# Only 0 words detected in mask_37.png. Deleting...
# Only 0 words detected in mask_38.png. Deleting...
# Only 0 words detected in mask_39.png. Deleting...
# Only 0 words detected in mask_4.png. Deleting...
# Only 0 words detected in mask_40.png. Deleting...
# Only 0 words detected in mask_41.png. Deleting...
# Only 0 words detected in mask_42.png. Deleting...
# Only 0 words detected in mask_43.png. Deleting...
# Only 0 words detected in mask_44.png. Deleting...
# Only 0 words detected in mask_45.png. Deleting...
# Only 0 words detected in mask_46.png. Deleting...
# Only 0 words detected in mask_47.png. Deleting...
# Only 0 words detected in mask_48.png. Deleting...
# Only 0 words detected in mask_49.png. Deleting...
# 3 words detected in mask_5.png. Keeping the image.
# Only 0 words detected in mask_50.png. Deleting...
# Only 0 words detected in mask_51.png. Deleting...
# Only 0 words detected in mask_52.png. Deleting...
# Only 0 words detected in mask_53.png. Deleting...
# Only 0 words detected in mask_54.png. Deleting...
# Only 1 words detected in mask_55.png. Deleting...
# Only 1 words detected in mask_56.png. Deleting...
# Only 0 words detected in mask_57.png. Deleting...
# Only 1 words detected in mask_58.png. Deleting...
# 45 words detected in mask_59.png. Keeping the image.
# Only 0 words detected in mask_6.png. Deleting...
# Only 0 words detected in mask_60.png. Deleting...
# 50 words detected in mask_7.png. Keeping the image.
# Image mask_8.png has a height 840 that is 4 times as large as its width 116. Deleting...
# Only 0 words detected in mask_9.png. Deleting...
# Skipping sat_0009_V0597557F_segmentation_visualization.png as it's not a target image.
# Collage saved to C:\\Users\\Riley\\Documents\\GitHub\\RileyHerbstProject\\DEMO\\Segmented_Images_Cleaned\final collages\sat_0009_V0597557F_collage.png
# Only 2 words detected in mask_1.png. Deleting...
# 72 words detected in mask_10.png. Keeping the image.
# Only 0 words detected in mask_100.png. Deleting...
# Only 0 words detected in mask_101.png. Deleting...
# Only 0 words detected in mask_102.png. Deleting...
# Only 0 words detected in mask_103.png. Deleting...
# Only 0 words detected in mask_104.png. Deleting...
# Only 0 words detected in mask_105.png. Deleting...
# Only 0 words detected in mask_106.png. Deleting...
# Only 0 words detected in mask_107.png. Deleting...
# Only 0 words detected in mask_108.png. Deleting...
# Only 0 words detected in mask_109.png. Deleting...
# Only 0 words detected in mask_11.png. Deleting...
# Only 0 words detected in mask_110.png. Deleting...
# Only 1 words detected in mask_111.png. Deleting...
# Only 0 words detected in mask_112.png. Deleting...
# Only 0 words detected in mask_113.png. Deleting...
# Only 0 words detected in mask_114.png. Deleting...
# Only 0 words detected in mask_115.png. Deleting...
# Only 0 words detected in mask_116.png. Deleting...
# Only 0 words detected in mask_117.png. Deleting...
# Only 0 words detected in mask_118.png. Deleting...
# Only 1 words detected in mask_119.png. Deleting...
# Only 0 words detected in mask_12.png. Deleting...
# Only 0 words detected in mask_120.png. Deleting...
# Only 0 words detected in mask_121.png. Deleting...
# Only 0 words detected in mask_122.png. Deleting...
# Only 1 words detected in mask_123.png. Deleting...
# Only 0 words detected in mask_124.png. Deleting...
# Only 0 words detected in mask_125.png. Deleting...
# Only 0 words detected in mask_126.png. Deleting...
# Only 0 words detected in mask_13.png. Deleting...
# Only 0 words detected in mask_14.png. Deleting...
# Only 0 words detected in mask_15.png. Deleting...
# Only 0 words detected in mask_16.png. Deleting...
# Only 0 words detected in mask_17.png. Deleting...
# Only 0 words detected in mask_18.png. Deleting...
# Only 0 words detected in mask_19.png. Deleting...
# Image mask_2.png has a height 821 that is 4 times as large as its width 110. Deleting...
# Only 0 words detected in mask_20.png. Deleting...
# Only 0 words detected in mask_21.png. Deleting...
# Only 0 words detected in mask_22.png. Deleting...
# Only 0 words detected in mask_23.png. Deleting...
# Only 0 words detected in mask_24.png. Deleting...
# Only 0 words detected in mask_25.png. Deleting...
# Only 0 words detected in mask_26.png. Deleting...
# Only 0 words detected in mask_27.png. Deleting...
# Only 0 words detected in mask_28.png. Deleting...
# Only 0 words detected in mask_29.png. Deleting...
# Only 0 words detected in mask_3.png. Deleting...
# Only 0 words detected in mask_30.png. Deleting...
# Only 0 words detected in mask_31.png. Deleting...
# Only 0 words detected in mask_32.png. Deleting...
# Only 0 words detected in mask_33.png. Deleting...
# Only 0 words detected in mask_34.png. Deleting...
# Only 0 words detected in mask_35.png. Deleting...
# Only 0 words detected in mask_36.png. Deleting...
# Only 0 words detected in mask_37.png. Deleting...
# Only 0 words detected in mask_38.png. Deleting...
# Only 0 words detected in mask_39.png. Deleting...
# Only 0 words detected in mask_4.png. Deleting...
# Only 0 words detected in mask_40.png. Deleting...
# Only 0 words detected in mask_41.png. Deleting...
# Only 0 words detected in mask_42.png. Deleting...
# Only 0 words detected in mask_43.png. Deleting...
# Only 0 words detected in mask_44.png. Deleting...
# Only 0 words detected in mask_45.png. Deleting...
# Only 0 words detected in mask_46.png. Deleting...
# Only 0 words detected in mask_47.png. Deleting...
# Only 0 words detected in mask_48.png. Deleting...
# Only 0 words detected in mask_49.png. Deleting...
# Image mask_5.png has a height 545 that is 4 times as large as its width 106. Deleting...
# Only 0 words detected in mask_50.png. Deleting...
# Only 0 words detected in mask_51.png. Deleting...
# Only 0 words detected in mask_52.png. Deleting...
# Only 0 words detected in mask_53.png. Deleting...
# Only 0 words detected in mask_54.png. Deleting...
# Only 0 words detected in mask_55.png. Deleting...
# Only 0 words detected in mask_56.png. Deleting...
# Only 0 words detected in mask_57.png. Deleting...
# Only 0 words detected in mask_58.png. Deleting...
# Only 0 words detected in mask_59.png. Deleting...
# Only 0 words detected in mask_6.png. Deleting...
# Only 0 words detected in mask_60.png. Deleting...
# Only 0 words detected in mask_61.png. Deleting...
# Only 0 words detected in mask_62.png. Deleting...
# Only 0 words detected in mask_63.png. Deleting...
# Only 1 words detected in mask_64.png. Deleting...
# Only 0 words detected in mask_65.png. Deleting...
# Only 0 words detected in mask_66.png. Deleting...
# Only 0 words detected in mask_67.png. Deleting...
# Only 1 words detected in mask_68.png. Deleting...
# Only 0 words detected in mask_69.png. Deleting...
# Only 0 words detected in mask_7.png. Deleting...
# Only 0 words detected in mask_70.png. Deleting...
# Only 0 words detected in mask_71.png. Deleting...
# Only 0 words detected in mask_72.png. Deleting...
# Only 0 words detected in mask_73.png. Deleting...
# Only 0 words detected in mask_74.png. Deleting...
# Only 0 words detected in mask_75.png. Deleting...
# Only 0 words detected in mask_76.png. Deleting...
# Only 0 words detected in mask_77.png. Deleting...
# Only 0 words detected in mask_78.png. Deleting...
# Only 0 words detected in mask_79.png. Deleting...
# Only 0 words detected in mask_8.png. Deleting...
# Only 0 words detected in mask_80.png. Deleting...
# Only 0 words detected in mask_81.png. Deleting...
# Only 0 words detected in mask_82.png. Deleting...
# Only 0 words detected in mask_83.png. Deleting...
# Only 0 words detected in mask_84.png. Deleting...
# Only 1 words detected in mask_85.png. Deleting...
# Only 1 words detected in mask_86.png. Deleting...
# Only 2 words detected in mask_87.png. Deleting...
# Only 1 words detected in mask_88.png. Deleting...
# Only 0 words detected in mask_89.png. Deleting...
# Only 2 words detected in mask_9.png. Deleting...
# Only 0 words detected in mask_90.png. Deleting...
# Only 0 words detected in mask_91.png. Deleting...
# Only 0 words detected in mask_92.png. Deleting...
# Only 0 words detected in mask_93.png. Deleting...
# Only 0 words detected in mask_94.png. Deleting...
# Only 0 words detected in mask_95.png. Deleting...
# Only 0 words detected in mask_96.png. Deleting...
# Only 0 words detected in mask_97.png. Deleting...
# Only 0 words detected in mask_98.png. Deleting...
# Only 0 words detected in mask_99.png. Deleting...
# Skipping sat_0010_V0594376F_segmentation_visualization.png as it's not a target image.
# Collage saved to C:\\Users\\Riley\\Documents\\GitHub\\RileyHerbstProject\\DEMO\\Segmented_Images_Cleaned\final collages\sat_0010_V0594376F_collage.png
# Skipping sat_0001_V0573776F_segmentation_visualization.png as it's not a target image.
# Skipping sat_0002_V0576008F_segmentation_visualization.png as it's not a target image.
# Skipping sat_0003_V0576279F_segmentation_visualization.png as it's not a target image.
# Skipping sat_0004_V0577013F_segmentation_visualization.png as it's not a target image.
# Skipping sat_0005_V0577892F_segmentation_visualization.png as it's not a target image.
# Skipping sat_0006_V0578553F_segmentation_visualization.png as it's not a target image.
# Skipping sat_0007_V0574052F_segmentation_visualization.png as it's not a target image.
# Skipping sat_0008_V0577681F_segmentation_visualization.png as it's not a target image.
# Skipping sat_0009_V0597557F_segmentation_visualization.png as it's not a target image.
# Skipping sat_0010_V0594376F_segmentation_visualization.png as it's not a target image.
