# %%
import os
import base64
import requests
import time

# %%
API_KEY = ""
MODEL_NAME = "gpt-4o"
SYSTEM_PROMPT_FILE = r"C:\\Users\\Riley\\Documents\\GitHub\\RileyHerbstProject\\Prompts\\SystemPrompt.txt"
USER_PROMPT_FILE = r"C:\\Users\\Riley\\Documents\\GitHub\\RileyHerbstProject\\Prompts\\Prompt_1.5.2.txt"

IMAGE_FOLDER = r"C:\\Users\\riley\\Documents\\GitHub\\RileyHerbstProject\\DEMO\\Output"

# %%
def read_text_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        return f.read()

def encode_image_to_base64(image_path):
    with open(image_path, "rb") as img_file:
        return base64.b64encode(img_file.read()).decode("utf-8")

def determine_type(image_path):
    ext = os.path.splitext(image_path)[1].lower()
    if ext == ".png":
        return "image/png"
    else:
        return "image/jpeg"

def get_image_files(folder_path):
    valid_extensions = (".jpg", ".jpeg", ".png")
    files = [filename for filename in os.listdir(folder_path)
             if os.path.isfile(os.path.join(folder_path, filename)) and filename.lower().endswith(valid_extensions)]
    return sorted(files)

system_prompt = read_text_file(SYSTEM_PROMPT_FILE)
user_prompt = read_text_file(USER_PROMPT_FILE)
image_files = get_image_files(IMAGE_FOLDER)
print(f"Found {len(image_files)} images.")

separator = "=" * 50 + "\n"

headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {API_KEY}"
}

start_time = time.time()


for idx, img_filename in enumerate(image_files, start=1):
        image_path = os.path.join(IMAGE_FOLDER, img_filename)
        encoded_image = encode_image_to_base64(image_path)
        image_type = determine_type(image_path)
        message_content = [
            {
                "type": "text",
                "text": user_prompt
            },
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:{image_type};base64,{encoded_image}"
                }
            }
        ]
        messages = [
            {
                "role": "system",
                "content": system_prompt
            },
            {
                "role": "user",
                "content": message_content
            }
        ]
        payload = {
            "model": MODEL_NAME,
            "messages": messages,
            "max_tokens": 4098,
            "temperature": 0.0,
            "seed": 42
        }
        print(f"Processing image {idx}: '{img_filename}'")
        response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)
        response_data = response.json()
        if "choices" in response_data and response_data["choices"]:
            assistant_reply = response_data["choices"][0].get("message", {}).get("content", "")
        else:
            assistant_reply = "No valid response returned from API."
        entry_text = (
            f"Entry {idx}\n"
            f"Image: {img_filename}\n"
            f"{assistant_reply}\n"
        )

        print(entry_text)
        print(f"Image {idx} processed.")

elapsed_time = time.time() - start_time
print(f"All images processed in {elapsed_time:.2f} seconds.")
# Out:
# Found 10 images.
# Processing image 1: 'sat_0001_V0573776F.jpg'
# Entry 1
# Image: sat_0001_V0573776F.jpg
# verbatimCollectors: Dr. Edgar A. Mearns
# collectedBy: E. A. Mearns
# secondaryCollectors: N/A
# recordNumber: 2832
# verbatimEventDate: Jan 15 to Feb 9 1909
# minimumEventDate: 1909-01-15
# maximumEventDate: 1909-02-09
# verbatimIdentification: Cyperus exaltatus Ridley
# latestScientificName: Cyperus maculatus
# identifiedBy: J. Raynal
# verbatimDateIdentified: 19.10.1971
# associatedTaxa: N/A
# country: South Sudan
# firstPoliticalUnit: Bahr el Jebel
# secondPoliticalUnit: N/A
# municipality: N/A
# verbatimLocality: Rhino Camp Lado Enclave Congo Free State
# locality: Rhino Camp
# habitat: N/A
# verbatimElevation: N/A
# verbatimCoordinates: N/A
# otherCatalogNumbers: 468360
# originalMethod: Typed
# typeStatus: N/A
#
# Image 1 processed.
# Processing image 2: 'sat_0002_V0576008F.jpg'
# Entry 2
# Image: sat_0002_V0576008F.jpg
# verbatimCollectors: COLL. F. G. OVERLAET
# collectedBy: F. G. Overlaet
# secondaryCollectors: N/A
# recordNumber: s.n.
# verbatimEventDate: 1923-24
# minimumEventDate: 1923-00-00
# maximumEventDate: 1924-00-00
# verbatimIdentification: Habenaria
# latestScientificName: Habenaria
# identifiedBy: B. Pettersson
# verbatimDateIdentified: 1984
# associatedTaxa: N/A
# country: Democratic Republic of the Congo
# firstPoliticalUnit: N/A
# secondPoliticalUnit: N/A
# municipality: N/A
# verbatimLocality: N/A
# locality: [precise locality unknown]
# habitat: N/A
# verbatimElevation: N/A
# verbatimCoordinates: N/A
# otherCatalogNumbers: 752356
# originalMethod: Mix of Handwritten and Typed
# typeStatus: no type status
#
# Image 2 processed.
# Processing image 3: 'sat_0003_V0576279F.jpg'
# Entry 3
# Image: sat_0003_V0576279F.jpg
# verbatimCollectors: Leg. R. A. Maas Geesteranus
# collectedBy: R. A. Maas Geesteranus
# secondaryCollectors: N/A
# recordNumber: 4924
# verbatimEventDate: 14-VI-1949
# minimumEventDate: 1949-06-14
# maximumEventDate: N/A
# verbatimIdentification: Pycreus segmentatus C. B. C.
# latestScientificName: Pycreus segmentatus
# identifiedBy: N/A
# verbatimDateIdentified: N/A
# associatedTaxa: Dombeya mastersii | Olea hochstetteri
# country: Kenya
# firstPoliticalUnit: Nyanza
# secondPoliticalUnit: Londiani
# municipality: N/A
# verbatimLocality: Tinderet Forest Reserve Camp I
# locality: Tinderet Forest Reserve Camp I
# habitat: Glade surrounded by rather open tall forest
# verbatimElevation: 2260 m s.m.
# verbatimCoordinates: lat. 0° 5' S long. 35° 27' E
# otherCatalogNumbers: 1447352
# originalMethod: Typed
# typeStatus: N/A
#
# Image 3 processed.
# Processing image 4: 'sat_0004_V0577013F.jpg'
# Entry 4
# Image: sat_0004_V0577013F.jpg
# verbatimCollectors: J. M. et R. Retima
# collectedBy: J. M.
# secondaryCollectors: R. Retima
# recordNumber: 2013
# verbatimEventDate: 3-3-85
# minimumEventDate: 1985-03-03
# maximumEventDate: N/A
# verbatimIdentification: Bulbophyllum scaberulum (Rolfe) Bolus var. scaberulum
# latestScientificName: Bulbophyllum scaberulum
# identifiedBy: O. Kosovsky
# verbatimDateIdentified: 2011
# associatedTaxa: N/A
# country: Gabon
# firstPoliticalUnit: N/A
# secondPoliticalUnit: N/A
# municipality: N/A
# verbatimLocality: 6 km NW of Ovanr chantier Rougier Océan
# locality: 6 kilometers northwest of Ovanr chantier Rougier Océan
# habitat: Primary rain forest
# verbatimElevation: N/A
# verbatimCoordinates: 0 41 N x 11 07 E
# otherCatalogNumbers: 2310219
# originalMethod: Typed
# typeStatus: N/A
#
# Image 4 processed.
# Processing image 5: 'sat_0005_V0577892F.jpg'
# Entry 5
# Image: sat_0005_V0577892F.jpg
# verbatimCollectors: Carvalho 2102
# collectedBy: Carvalho
# secondaryCollectors: N/A
# recordNumber: 2102
# verbatimEventDate: 26-VII-1986
# minimumEventDate: 1986-07-26
# maximumEventDate: N/A
# verbatimIdentification: Mariscus alternifolius Vahl
# latestScientificName: Mariscus alternifolius
# identifiedBy: C. Cebolla | M. A. Rivas Ponce
# verbatimDateIdentified: 1995
# associatedTaxa: N/A
# country: Equatorial Guinea
# firstPoliticalUnit: Bioco
# secondPoliticalUnit: N/A
# municipality: Malabo
# verbatimLocality: Malabo finca las Carboneras 32NMK7415
# locality: Finca las Carboneras
# habitat: Bosque secundario y terrenos incultos Herbácea 20-30 cm
# verbatimElevation: 8 m
# verbatimCoordinates: N/A
# otherCatalogNumbers: 2201108
# originalMethod: Typed
# typeStatus: N/A
#
# Image 5 processed.
# Processing image 6: 'sat_0006_V0578553F.jpg'
# Entry 6
# Image: sat_0006_V0578553F.jpg
# verbatimCollectors: Fernández Casas 11206
# collectedBy: N/A
# secondaryCollectors: N/A
# recordNumber: 11206
# verbatimEventDate: 5-11-1989
# minimumEventDate: 1989-11-05
# maximumEventDate: N/A
# verbatimIdentification: Agrostis manii (Hooker fil.) Stapf
# latestScientificName: Agrostis manii
# identifiedBy: C. Cebolla | M. A. Rivas Ponce
# verbatimDateIdentified: 1993
# associatedTaxa: N/A
# country: Equatorial Guinea
# firstPoliticalUnit: Bioco
# secondPoliticalUnit: N/A
# municipality: N/A
# verbatimLocality: cumbre del pico Basilé 32NMJ7396 2870 m márgenes de la pista
# locality: Cumbre del pico Basilé
# habitat: márgenes de la pista
# verbatimElevation: 2870 m
# verbatimCoordinates: 32NMJ7396
# otherCatalogNumbers: 2200806
# originalMethod: Typed
# typeStatus: N/A
#
# Image 6 processed.
# Processing image 7: 'sat_0007_V0574052F.jpg'
# Entry 7
# Image: sat_0007_V0574052F.jpg
# verbatimCollectors: COLL. F. G. Overlaet
# collectedBy: F. G. Overlaet
# secondaryCollectors: N/A
# recordNumber: s.n.
# verbatimEventDate: 1923-4
# minimumEventDate: 1923-04-00
# maximumEventDate: N/A
# verbatimIdentification: Scirpus
# latestScientificName: Scirpus mucronatus
# identifiedBy: A. E. Schuyler
# verbatimDateIdentified: 1964
# associatedTaxa: N/A
# country: Democratic Republic of the Congo
# firstPoliticalUnit: N/A
# secondPoliticalUnit: N/A
# municipality: N/A
# verbatimLocality: N/A
# locality: [precise locality unknown]
# habitat: N/A
# verbatimElevation: N/A
# verbatimCoordinates: N/A
# otherCatalogNumbers: 752378
# originalMethod: Typed
# typeStatus: N/A
#
# Image 7 processed.
# Processing image 8: 'sat_0008_V0577681F.jpg'
# Entry 8
# Image: sat_0008_V0577681F.jpg
# verbatimCollectors: Collected by C.J.P. Sosef
# collectedBy: C. J. P. Sosef
# secondaryCollectors: N/A
# recordNumber: 2806
# verbatimEventDate: 23 October 1972
# minimumEventDate: 1972-10-23
# maximumEventDate: N/A
# verbatimIdentification: Vernonia abyssinica Sch. Bip.
# latestScientificName: Vernonia abyssinica
# identifiedBy: G. J. H. Amshoff
# verbatimDateIdentified: 1982
# associatedTaxa: N/A
# country: Ethiopia
# firstPoliticalUnit: Shewa
# secondPoliticalUnit: N/A
# municipality: N/A
# verbatimLocality: c. 3 km from Metahara on road to Nazareth
# locality: 3 kilometers from Metahara on road to Nazareth
# habitat: In full sun on a lava rock
# verbatimElevation: c. 825 m
# verbatimCoordinates: 8°36' N 39°55' E
# otherCatalogNumbers: 2302805
# originalMethod: Typed
# typeStatus: N/A
#
# Image 8 processed.
# Processing image 9: 'sat_0009_V0597557F.jpg'
# Entry 9
# Image: sat_0009_V0597557F.jpg
# verbatimCollectors: N/A
# collectedBy: N/A
# secondaryCollectors: N/A
# recordNumber: 48
# verbatimEventDate: 05.08.2007
# minimumEventDate: 2007-08-05
# maximumEventDate: N/A
# verbatimIdentification: Cirsium lepidacanthum Fres
# latestScientificName: Cirsium lepidacanthum
# identifiedBy: N/A
# verbatimDateIdentified: N/A
# associatedTaxa: N/A
# country: Democratic Republic of the Congo
# firstPoliticalUnit: Sud-Kivu
# secondPoliticalUnit: Kabare
# municipality: N/A
# verbatimLocality: Musisi
# locality: Musisi
# habitat: N/A
# verbatimElevation: N/A
# verbatimCoordinates: N/A
# otherCatalogNumbers: 2257689
# originalMethod: Typed
# typeStatus: no type status
#
# Image 9 processed.
# Processing image 10: 'sat_0010_V0594376F.jpg'
# Entry 10
# Image: sat_0010_V0594376F.jpg
# verbatimCollectors: J. M. Fay
# collectedBy: J. M. Fay
# secondaryCollectors: N/A
# recordNumber: 8017
# verbatimEventDate: 25 May 1987
# minimumEventDate: 1987-05-25
# maximumEventDate: N/A
# verbatimIdentification: Burkea africana Hook.
# latestScientificName: Burkea africana
# identifiedBy: J. M. Fay
# verbatimDateIdentified: N/A
# associatedTaxa: N/A
# country: Central African Republic
# firstPoliticalUnit: N/A
# secondPoliticalUnit: N/A
# municipality: N/A
# verbatimLocality: Park Manovo-Gounda-St. Floris. Vicinity of Camp Koumbala.
# locality: Park Manovo-Gounda-St. Floris Vicinity of Camp Koumbala
# habitat: N/A
# verbatimElevation: prec: 1200 m elev: 600 m
# verbatimCoordinates: 08°29'N 21°12'E
# otherCatalogNumbers: NCI# Wood Q678/0065 Bark Q678/0066 Root Q678/0067 Leaves Q678/0068
# originalMethod: Typed
# typeStatus: N/A
#
# Image 10 processed.
# All images processed in 114.95 seconds.
